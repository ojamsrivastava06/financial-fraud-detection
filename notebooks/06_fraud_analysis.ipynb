# %% [markdown]
# # 06 - Advanced Fraud Pattern & Risk Analysis
#
# Notebook for location heatmaps, merchant risk tiers, and business impact estimation
#
# **Status**: Phase 1 Skeleton Placeholder

# %%
import pandas as pd
import numpy as np
from src.config.settings import settings
from src.data.ingestion import load_raw_dataset

# TODO [PHASE 2]: Execute notebook workflow
print(f'Raw dataset path: {settings.DATA_PATH}')
