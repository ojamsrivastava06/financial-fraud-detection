# %% [markdown]
# # 05 - Model Evaluation, Threshold Optimization & Risk Scoring
# Evaluates candidate model performance on test set, analyzes ROC/PR curves, optimizes decision operating thresholds, extracts feature importances, and demonstrates risk tier scoring.

# %%
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ROOT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

from src.models.model_registry import ModelRegistry
from src.models.predict import predict_fraud_probability
from src.models.risk_scoring import calculate_risk_score

# %% [markdown]
# ## 1. Load Model Comparison & Benchmark Results
# Inspect test set PR-AUC, ROC-AUC, Precision, Recall, and F1 scores across models.

# %%
comp_path = ROOT_DIR / 'reports' / 'model_reports' / 'model_comparison.csv'
df_comp = pd.read_csv(comp_path)
df_comp

# %% [markdown]
# ## 2. Threshold Sensitivity Analysis
# Inspect decision threshold optimization table.

# %%
th_path = ROOT_DIR / 'reports' / 'model_reports' / 'threshold_analysis.csv'
df_th = pd.read_csv(th_path)
df_th.head(10)

# %% [markdown]
# ## 3. Feature Importance / Coefficient Ranking
# Display top predictive features for fraud detection.

# %%
imp_path = ROOT_DIR / 'reports' / 'model_reports' / 'feature_importance.csv'
df_imp = pd.read_csv(imp_path)
df_imp.head(10)

# %% [markdown]
# ## 4. End-to-End Prediction & Risk Level Demonstration
# Demonstrate probability prediction and risk scoring for sample transaction payload.

# %%
sample_payload = {
    'Transaction_Amount': 450.0,
    'Merchant_Category': 'Travel',
    'Payment_Method': 'Credit Card',
    'Device_Type': 'POS',
    'Location': 'Bengaluru',
    'Is_International': 1,
    'Previous_Transactions': 10,
    'Average_Spend': 50.0,
    'Account_Age_Days': 100,
    'Suspicious_Keyword': 'Yes'
}
res = predict_fraud_probability(sample_payload)
print('Inference Output:', res)
